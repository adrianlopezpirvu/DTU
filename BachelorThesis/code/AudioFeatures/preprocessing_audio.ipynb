# %%
import re
import os
import zipfile
from scipy.io import wavfile
import tempfile
import pandas as pd
import noisereduce as nr                   
from pydub import AudioSegment
from pydub import AudioSegment
import numpy as np
import zipfile

# %% [markdown]
# **Final**

# %%
class AudioProcessor:

    def __init__(self, input_directory='../Data', output_directory='../Results/Final/noise_kept_all/'):
        """
        Initialize the AudioProcessor class.

        Args:
            input_directory (str): Directory containing the ZIP folders.
            output_directory (str): Output directory for saving denoised audio files.
        """
        self.input_directory = input_directory
        self.output_directory = output_directory
        os.makedirs(self.output_directory, exist_ok=True)

        self.output_audio_directory = output_directory + 'audio/'
        self.output_csv_directory = output_directory + 'csv/'

        os.makedirs(self.output_audio_directory, exist_ok=True)
        os.makedirs(self.output_csv_directory, exist_ok=True)
    
    def only_participant(self, file_path, transcript_path, file_number, return_silence_csv=True):
        audio  = AudioSegment.from_wav(file_path)
        rate, _ = wavfile.read(file_path)
        df = pd.read_csv(transcript_path, delimiter='\t')
        # Filter the participant's intervals
        participant_intervals = df[df["speaker"] == "Participant"]

        # Create an audio segment with the participant's intervals
        participant_audio = AudioSegment.silent(duration=0)  # Initialize an empty segment

        for _, row in participant_intervals.iterrows():
            start_time = int(row["start_time"] * 1000)  # Convert to milliseconds
            stop_time = int(row["stop_time"] * 1000)
            participant_audio += audio[start_time:stop_time]

        if return_silence_csv:
            silence_data = []
            # Iterate through each row in the DataFrame except the last one
            for i in range(len(df) - 1):
                if df['speaker'][i] == 'Ellie' and df['speaker'][i+1] == 'Participant':
                    silence = {
                        'start_time': df['stop_time'][i],
                        'end_time': df['start_time'][i+1],
                        'duration': df['start_time'][i+1] - df['stop_time'][i],
                        'to_respond': 1   # between Ellie and Participant
                    }
                    silence_data.append(silence)
                elif df['speaker'][i] == 'Participant' and df['speaker'][i+1] == 'Participant':
                    silence = {
                        'start_time': df['stop_time'][i],
                        'end_time': df['start_time'][i+1],
                        'duration': df['start_time'][i+1] - df['stop_time'][i],
                        'to_respond': 0   # between Participant and Participant
                    }
                    silence_data.append(silence)

            # Create DataFrame from the list of dictionaries
            df_silence = pd.DataFrame(silence_data)

            # Optionally, sort by start_time
            df_silence = df_silence.sort_values(by='start_time').reset_index(drop=True)

            # Save the DataFrame to a CSV file
            csv_path = os.path.join(self.output_csv_directory, f"{file_number}_silence.csv")       
            df_silence.to_csv(csv_path, index=False)

        return participant_audio, rate

    def remove_noise(self, data, rate):
        data = np.array(data.get_array_of_samples())
        if len(data.shape) > 1:
            data = data[:, 0]
        reduced_noise = nr.reduce_noise(y=data, sr=rate)
        return reduced_noise
    
    def save_audio(self, audio, file_number):
        # Create the path for the audio file
        audio_path = os.path.join(self.output_audio_directory, f"{file_number}.wav")
        audio.export(audio_path, format="wav")
        print(f"Audio saved as {file_number}.wav")
        print('---' * 30)
        return None
    

    def process_audio(self, remove_intro=True, remove_noise=False):
        for zip_file in os.listdir(self.input_directory):
            if zip_file.endswith('.zip'):
                zip_file_path = os.path.join(self.input_directory, zip_file)

                with tempfile.TemporaryDirectory() as temp_dir:
                    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
                        zip_ref.extractall(temp_dir)

                    for root, dirs, files in os.walk(temp_dir):
                        for filename in files:
                            # Extract the number from the file name
                               
                            if filename.endswith('.wav'):
                                file_number = re.search(r'\d+', filename).group() if re.search(r'\d+', filename) else None
                                file_path = os.path.join(root, filename)
         
                                if remove_intro:
                                    for root, dirs, files in os.walk(temp_dir):
                                        # Find TRANSCRIPT.csv and set time_interview_starts if found
                                        for filename in files:
                                            if filename.endswith('TRANSCRIPT.csv'):
                                                transcript_path = os.path.join(root, filename)
                                                break  # Stop searching for TRANSCRIPT.csv once found

                                    data, rate = self.only_participant(file_path, transcript_path, file_number, return_silence_csv=True)

                                if remove_noise:
                                    data = self.remove_noise(data, rate)
                                else:
                                    data = np.array(data.get_array_of_samples())
                                    if len(data.shape) > 1:
                                        data = data[:, 0]
                                audio = AudioSegment(data.tobytes(), frame_rate=rate, sample_width=data.dtype.itemsize, channels=1)
                                self.save_audio(audio, file_number)

# %% [markdown]
# **Transcript and AUs files extraction**

# %%
def extract_files(zip_dir, output_dir_transcript, output_dir_clnf_aus, extensions):
    """
    Extracts files with specified extensions from zip files in a directory to specified output directories.
    
    Parameters:
    zip_dir (str): Directory containing zip files.
    output_dir_transcript (str): Directory to save the extracted TRANSCRIPT.csv files.
    output_dir_clnf_aus (str): Directory to save the extracted CLNF_AUs.txt files.
    extensions (dict): Dictionary with extensions as keys and output directories as values.
    """
    for output_dir in extensions.values():
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

    for item in os.listdir(zip_dir):
        if item.endswith('.zip'):
            zip_path = os.path.join(zip_dir, item)
            with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                for file_name in zip_ref.namelist():
                    for ext, out_dir in extensions.items():
                        if file_name.endswith(ext):
                            zip_ref.extract(file_name, out_dir)
                            print(f"Extracted {file_name} to {out_dir}")

if __name__ == "__main__":
    zip_directory = "../Data"
    output_directory_transcript = "../Results/Final/Transcripts"
    output_directory_clnf_aus = "../Results/Final/AUs"
    file_extensions = {
        "TRANSCRIPT.csv": output_directory_transcript,
        "CLNF_AUs.txt": output_directory_clnf_aus
    }

    extract_files(zip_directory, output_directory_transcript, output_directory_clnf_aus, file_extensions)
# Out:
# Extracted 300_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 300_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 301_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 301_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 302_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 302_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 303_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 303_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 304_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 304_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 305_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 305_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 306_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 306_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 307_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 307_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 308_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 308_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 309_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 309_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 310_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 310_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 311_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 311_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 312_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 312_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 313_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 313_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 314_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 314_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 315_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 315_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 316_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 316_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 317_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 317_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 318_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 318_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 319_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 319_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 320_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 320_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 321_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 321_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 322_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 322_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 323_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 323_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 324_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 324_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 325_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 325_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 326_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 326_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 327_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 327_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 328_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 328_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 329_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 329_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 330_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 330_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 331_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 331_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 332_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 332_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 333_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 333_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 334_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 334_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 335_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 335_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 336_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 336_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 337_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 337_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 338_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 338_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 339_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 339_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 340_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 340_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 341_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 341_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 343_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 343_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 344_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 344_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 345_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 345_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 346_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 346_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 347_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 347_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 348_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 348_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 349_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 349_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 350_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 350_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 351_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 351_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 352_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 352_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 353_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 353_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 354_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 354_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 355_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 355_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 356_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 356_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 360_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 360_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 361_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 361_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 362_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 362_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 363_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 363_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 364_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 364_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 366_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 366_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 367_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 367_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 368_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 368_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 369_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 369_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 370_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 370_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 371_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 371_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 372_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 372_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 373_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 373_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 374_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 374_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 375_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 375_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 376_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 376_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 377_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 377_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 378_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 378_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 379_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 379_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 380_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 380_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 381_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 381_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 383_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 383_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 384_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 384_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 385_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 385_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 386_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 386_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 387_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 387_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 388_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 388_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 389_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 389_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 390_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 390_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 391_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 391_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 392_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 392_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 393_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 393_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 395_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 395_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 396_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 396_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 397_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 397_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 399_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 399_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 400_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 400_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 401_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 401_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 402_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 402_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 403_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 403_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 404_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 404_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 405_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 405_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 406_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 406_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 407_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 407_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 408_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 408_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 409_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 409_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 410_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 410_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 411_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 411_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 412_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 412_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 413_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 413_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 414_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 414_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 415_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 415_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 416_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 416_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 417_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 417_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 418_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 418_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 419_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 419_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 420_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 420_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 421_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 421_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 422_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 422_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 423_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 423_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 424_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 424_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 425_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 425_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 426_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 426_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 427_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 427_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 428_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 428_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 429_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 429_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 430_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 430_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 431_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 431_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 432_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 432_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 433_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 433_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 434_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 434_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 435_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 435_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 436_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 436_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 437_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 437_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 438_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 438_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 439_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 439_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 440_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 440_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 441_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 441_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 442_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 442_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 443_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 443_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 444_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 444_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 445_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 445_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 446_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 446_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 447_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 447_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 448_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 448_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 449_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 449_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 450_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 450_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 451_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 451_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 452_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 452_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 453_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 453_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 454_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 454_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 455_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 455_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 456_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 456_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 457_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 457_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 458_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 458_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 459_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 459_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 461_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 461_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 462_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 462_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 463_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 463_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 464_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 464_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 465_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 465_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 466_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 466_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 467_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 467_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 468_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 468_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 469_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 469_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 470_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 470_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 471_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 471_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 472_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 472_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 473_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 473_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 474_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 474_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 475_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 475_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 476_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 476_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 477_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 477_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 478_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 478_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 479_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 479_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 480_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 480_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 481_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 481_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 482_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 482_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 483_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 483_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 484_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 484_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 485_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 485_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 486_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 486_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 487_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 487_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 488_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 488_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 489_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 489_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 490_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 490_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 491_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 491_TRANSCRIPT.csv to ../Results/Final/Transcripts
# Extracted 492_CLNF_AUs.txt to ../Results/Final/AUs
# Extracted 492_TRANSCRIPT.csv to ../Results/Final/Transcripts

# %%
def cargar_audio(file_path):
        rate, data = wavfile.read(file_path)
        return rate, data

_ ,audio_data = cargar_audio('../Data/300_P/300_AUDIO.wav')

audio_file = '../Data/300_P/300_AUDIO.wav'
sound = AudioSegment.from_wav(audio_file)

# Comparar si sound y audio_data son iguales
print(sound == audio_data)
# Out:
# False

# %%
# Read the transcript file
df = pd.read_csv('../Data/300_P/300_TRANSCRIPT.csv',delimiter='\t')

# Filter the participant's intervals
participant_intervals = df[df["speaker"] == "Participant"]

# Load the audio file
audio_file = '../Data/300_P/300_AUDIO.wav'
sound = AudioSegment.from_wav(audio_file)

# Create an audio segment with the participant's intervals
participant_audio = AudioSegment.silent(duration=0)  # Initialize an empty segment

for _, row in participant_intervals.iterrows():
    start_time = int(row["start_time"] * 1000)  # Convert to milliseconds
    stop_time = int(row["stop_time"] * 1000)
    participant_audio += sound[start_time:stop_time]

# Save the participant's audio as a WAV file
participant_audio.export("participant_audio.wav", format="wav")
# Out:
# <_io.BufferedRandom name='participant_audio.wav'>

# %%
# Read the CSV file
df = pd.read_csv('../Data/300_P/300_TRANSCRIPT.csv', delimiter="\t")

# %%
# Initialize an empty list to store dictionaries representing periods of silence
silence_data = []

# Iterate through each row in the DataFrame except the last one
for i in range(len(df) - 1):
    if df['speaker'][i] == 'Ellie' and df['speaker'][i+1] == 'Participant':
        silence = {
            'start_time': df['stop_time'][i],
            'end_time': df['start_time'][i+1],
            'duration': df['start_time'][i+1] - df['stop_time'][i],
            'to_respond': 1   # between Ellie and Participant
        }
        silence_data.append(silence)
    elif df['speaker'][i] == 'Participant' and df['speaker'][i+1] == 'Participant':
        silence = {
            'start_time': df['stop_time'][i],
            'end_time': df['start_time'][i+1],
            'duration': df['start_time'][i+1] - df['stop_time'][i],
            'to_respond': 0   # between Participant and Participant
        }
        silence_data.append(silence)

# Create DataFrame from the list of dictionaries
df_silence = pd.DataFrame(silence_data)


# Optionally, sort by start_time
df_silence = df_silence.sort_values(by='start_time').reset_index(drop=True)

# df_silence now contains the periods of silence as a DataFrame
print(df_silence)
# Out:
#     start_time  end_time  duration  to_respond
# 0       61.378    62.328      0.95           1
# 1       67.528    68.978      1.45           1
# 2       74.198    75.028      0.83           1
# 3       83.578    83.808      0.23           1
# 4       87.898    88.458      0.56           1
# ..         ...       ...       ...         ...
# 82     590.918   598.238      7.32           1
# 83     599.708   600.608      0.90           0
# 84     602.688   602.738      0.05           1
# 85     616.878   618.308      1.43           1
# 86     620.348   620.538      0.19           1
#
# [87 rows x 4 columns]
